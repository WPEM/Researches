# %%
import sys
import pandas as pd
Yourdir = '/Users/jacob/Documents/GitHub/'
sys.path.append(Yourdir)
from PyWPEM import WPEM
# Out:
# ██╗    ██╗██████╗ ███████╗███╗   ███╗
# ██║    ██║██╔══██╗██╔════╝████╗ ████║
# ██║ █╗ ██║██████╔╝█████╗  ██╔████╔██║
# ██║███╗██║██╔═══╝ ██╔══╝  ██║╚██╔╝██║
# ╚███╔███╔╝██║     ███████╗██║ ╚═╝ ██║
#  ╚══╝╚══╝ ╚═╝     ╚══════╝╚═╝     ╚═╝
#
# A Diffraction Refinement Software : WPEM
# Bin Cao, Advanced Materials Thrust, Hong Kong University of Science and Technology (Guangzhou)
# URL : https://github.com/Bin-Cao/WPEM
# Executed on : 2024-06-27 10:15:08  | Have a great day.
# ====================================================================================================

# %%
_,_,_ = WPEM.XRDSimulation(filepath='Li2MnO3.cif',two_theta_range=(10, 90, 0.01),GrainSize=10,)
# Out:
# the space group of input crystal is : C2/m
# cif file parse completed
# atom locations claculated by parsed cif file
# retrieval of all reciprocal vectors satisfying the diffraction geometry is done
# extinction peaks are distinguished
# There are 91 extinction peaks
# Diffraction condition judgment end !
# The input crystal system is: Monoclinic  |  The initial lattice constants : 4.93886 8.53453 5.02985 90.0 109.46427 90.0
#
#
# WPEM simulates the peaks as the default Voigt functions
# Initilized with default peak's shape
# The nearest neighbor atoms are : ['Mn4+', 'O2-', 1.9026]
# XRD simulation process of WPEM is completed !

# %%
_,_,_ = WPEM.XRDSimulation(filepath='LiTMO2.cif',two_theta_range=(10, 90, 0.01),GrainSize=10,)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 _,_,_ = WPEM.XRDSimulation(filepath='LiTMO2.cif',two_theta_range=(10, 90, 0.01),GrainSize=10,)
#
# File ~/Documents/GitHub/PyWPEM/WPEM.py:350, in XRDSimulation(filepath, wavelength, two_theta_range, SuperCell, PeriodicArr, ReSolidSolution, RSSratio, Vacancy, Vacancy_atom, Vacancy_ratio, GrainSize, LatticCs, PeakWidth, CSWPEMout, orientation, thermo_vib, zero_shift, bacI, seed)
#     308 def XRDSimulation(filepath,wavelength='CuKa',two_theta_range=(10, 90, 0.01),SuperCell=False,PeriodicArr=[3,3,3],ReSolidSolution = None, RSSratio=0.1, Vacancy=False, Vacancy_atom = None, Vacancy_ratio = None,GrainSize = None,LatticCs = None,PeakWidth=True, CSWPEMout = None,orientation=None,thermo_vib=None,zero_shift = None, bacI=False,seed=42):
#     309     """
#     310     :param filepath (str): file path of the cif file to be calculated
#     311     :param two_theta_range ([float of length 2]): Tuple for range of
#    (...)
#     348     return : Structure factors
#     349     """
# --> 350     return XRD_profile(filepath,wavelength,two_theta_range,SuperCell,PeriodicArr,ReSolidSolution, RSSratio, GrainSize,LatticCs,PeakWidth, CSWPEMout).Simulate(Vacancy=Vacancy, Vacancy_atom = Vacancy_atom, Vacancy_ratio = Vacancy_ratio,orientation=orientation,thermo_vib=thermo_vib,zero_shift = zero_shift, bacI=bacI,seed=seed)
#
# File ~/Documents/GitHub/PyWPEM/XRDSimulation/Simulation.py:52, in XRD_profile.__init__(self, filepath, wavelength, two_theta_range, SuperCell, PeriodicArr, ReSolidSolution, RSSratio, GrainSize, LatticCs, PeakWidth, CSWPEMout)
#      50 _range = (two_theta_range[0],two_theta_range[1])
#      51 if LatticCs == None:
# ---> 52     LatticCs, Atom_coordinate,_ = profile(wavelength,_range).generate(filepath)
#      53 elif type(LatticCs) == list and len(LatticCs) == 6 :
#      54     _, Atom_coordinate = profile(wavelength,_range).generate(filepath)
#
# File ~/Documents/GitHub/PyWPEM/Extinction/XRDpre.py:88, in profile.generate(self, filepath, latt, Asymmetric_atomic_coordinates)
#      86     print('Need to specify the file (.cif) path to be processed')
#      87 else:
# ---> 88     latt, space_g, Asymmetric_atomic_coordinates,Point_group, symmetric_operation = read_cif(filepath)
#      89     if space_g != None:
#      90         print('the space group of input crystal is :',space_g )
#
# File ~/Documents/GitHub/PyWPEM/Extinction/XRDpre.py:214, in read_cif(cif_dir)
#     211         symbol = None
#     212         spaceG = None
# --> 214 return latt, spaceG, sites, symbol,symmetric_operation
#
# UnboundLocalError: local variable 'latt' referenced before assignment
